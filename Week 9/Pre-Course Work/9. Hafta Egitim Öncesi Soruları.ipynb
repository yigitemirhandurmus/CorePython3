# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
# 1.Problemin Çözümünü Buraya Yazınız

class Vehicle():
    class Bus():
        def seating_capacity():
            seatingCapacity = 50
            print(f"The seating capacity of a bus is {seatingCapacity} passengers")

Vehicle.Bus.seating_capacity()
# Out:
# The seating capacity of a bus is 50 passengers

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

try:
    if School_bus() in Vehicle():
        print("İlgili sınıf Vehicle sınıfının bir örneği.")
except TypeError:
    print("İlgili sınıf Vehicle sınıfının bir örneği değil.")
# Out:
# İlgili sınıf Vehicle sınıfının bir örneği değil.
